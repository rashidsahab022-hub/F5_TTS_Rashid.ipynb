# %%
# ✅ F5-TTS Full Auto Setup (Optimized for Google Colab)

# 1️⃣ Clean any old installations
# !pip uninstall -y torch torchvision torchaudio

# 2️⃣ Install working PyTorch version (CUDA 12.1 supported - works on CPU too)
# !pip install torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2 --index-url https://download.pytorch.org/whl/cu121

# 3️⃣ Install F5-TTS (latest stable)
# !pip install git+https://github.com/SWivid/F5-TTS.git

# 4️⃣ Clear setup logs for a clean output
from IPython.display import clear_output
clear_output()
print('✅ Installation done successfully!')
print('🚀 Launching Gradio voice interface...')

# 5️⃣ Start the app (with public share link)
# !f5-tts_infer-gradio --share
