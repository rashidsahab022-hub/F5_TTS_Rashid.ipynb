# %%
# ==============================
# ✅ F5-TTS Working Auto Setup (Fixed Version)
# ==============================

# Clean previous installations
# !pip uninstall -y torch torchvision torchaudio

# Install compatible PyTorch (CUDA 12.1 build - works on CPU or GPU both)
# !pip install torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2 --index-url https://download.pytorch.org/whl/cu121

# Install F5-TTS directly from GitHub (latest version)
# !pip install git+https://github.com/SWivid/F5-TTS.git

# Clear any leftover logs or errors
from IPython.display import clear_output
clear_output()
print('✅ Installation completed successfully. Launching Gradio interface...')

# Launch the Gradio voice generation app (with public share link)
# !f5-tts_infer-gradio --share
